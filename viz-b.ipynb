# %%
import pandas as pd
import numpy as num
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars = pd.read_csv('./b -All_cars_dataset.csv')
cars.head()
# Out:
#                     Name       EMI       Price       Mileage  \
# 0          Porsche Macan  1,18,950  69.98 Lakh      14 kmpl
# 1            Porsche 718  1,45,262  85.46 Lakh       9 kmpl
# 2        Porsche Cayenne  2,02,272   1.2 Crore  9 - 40 kmpl
# 3  Porsche Cayenne Coupe  2,24,165  1.32 Crore    10.75 kmpl
# 4       Porsche Panamera  2,45,599  1.44 Crore     8-37 kmpl
#
#              ENGINE        TRANSMISSION FUEL TYPE                 Price range  \
# 0  1984 to 2995 cc           Automatic    Petrol        ₹ 69.98 - 85.01 Lakh
# 1  1988 to 3995 cc   Automatic, Manual    Petrol   ₹ 85.46 Lakh - 1.64 Crore
# 2  2995 to 3996 cc           Automatic    Petrol          ₹ 1.2 - 1.93 Crore
# 3  2995 to 3996 cc           Automatic    Petrol         ₹ 1.32 - 1.98 Crore
# 4  2894 to 4806 cc           Automatic    Petrol         ₹ 1.44 - 2.43 Crore
#
#    Length (mm) Wheelbase (mm)  ... Fuel Capacity (L)  Height (mm)  \
# 0         4696           2807  ...                75         1624
# ...

# %% [markdown]
# ### Top 5 cheapest cars

# %%
bar_plot_data_1 = cars.sort_values('Price').head(5)
bar_plot_data_1
sns.scatterplot(x='Name', y='Price', data = bar_plot_data_1)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Price'>

# %% [markdown]
# ### Top 5 fastest cars

# %%
bar_plot_data_2 = cars.sort_values('Top_Speed').tail(5)
bar_plot_data_2
sns.scatterplot(x='Name', y='Top_Speed', data = bar_plot_data_2)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Top_Speed'>

# %% [markdown]
# ### Top 5 cars with highest mileage

# %%
bar_plot_data_3 = cars.sort_values('Mileage').tail(5)
bar_plot_data_3
sns.scatterplot(x='Name', y='Mileage', data = bar_plot_data_2)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Mileage'>
