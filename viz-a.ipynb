# %%
import pandas as pd
import numpy as num
import matplotlib.pyplot as plt
import seaborn

# %%
books = pd.read_csv('a_bestsellers with categories.csv')
books.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
data_bar_plot = books.groupby('Name',as_index=False).mean('User Rating').sort_values('User Rating',ascending='False').tail(5)
data_bar_plot
# Out:
#                                                   Name  User Rating  Reviews  \
# 312                   The Wonderful Things You Will Be          4.9   8842.0
# 151  Last Week Tonight with John Oliver Presents A ...          4.9  11881.0
# 159                                  Little Blue Truck          4.9   1884.0
# 330                             Unfreedom of the Press          4.9   5956.0
# 208             Strange Planet (Strange Planet Series)          4.9   9382.0
#
#      Price    Year
# 312   10.0  2017.5
# 151   13.0  2018.0
# 159    0.0  2014.0
# 330   11.0  2019.0
# 208    6.0  2019.0

# %% [markdown]
# ### This visual shows the prices of 5 highly rated books

# %%
seaborn.barplot(x='Price', y='Name', data = data_bar_plot)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Name'>
# /home/aseelalzweri/data-visulization/.venv/lib/python3.8/site-packages/matplotlib/textpath.py:65: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=LOAD_NO_HINTING)
# /home/aseelalzweri/data-visulization/.venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/aseelalzweri/data-visulization/.venv/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 146 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
data_bar_plot_2 = books.groupby('Year',as_index=False).mean('Price')
data_bar_plot_2
# Out:
#     Year  User Rating   Reviews  Price
# 0   2009        4.584   4710.12  15.40
# 1   2010        4.558   5479.62  13.48
# 2   2011        4.558   8100.82  15.10
# 3   2012        4.532  13090.92  15.30
# 4   2013        4.554  13098.14  14.60
# 5   2014        4.622  15859.94  14.64
# 6   2015        4.648  14233.38  10.42
# 7   2016        4.678  14196.00  13.18
# 8   2017        4.660  12888.40  11.38
# 9   2018        4.668  13930.42  10.52
# 10  2019        4.740  15898.34  10.08

# %% [markdown]
# This visual shows average book prices over a ten-year time period. It is clear are not highly affected with time.

# %%
seaborn.barplot(x='Year', y='Price', data = data_bar_plot_2)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Price'>

# %%
data_bar_plot_3 = books.groupby('Author',as_index=False).max('User Rating').sort_values('User Rating',ascending='False').head(5)
data_bar_plot_3
# Out:
#              Author  User Rating  Reviews  Price  Year
# 71      Donna Tartt          3.9    33844     20  2014
# 100   Gillian Flynn          4.0    57271     10  2014
# 171  Muriel Barbery          4.0     1859     11  2009
# 90           Gallup          4.0     5069     17  2017
# 180   Paula Hawkins          4.1    79446     18  2016

# %% [markdown]
# ### This visual shows year in which authors Donna Tartt, Gillian Flynn, Muriel Barbery, Gallup and Paula Hawkins published their best book.

# %%
seaborn.boxplot(x='Author', y='Year', data= data_bar_plot_3)
# Out:
# <AxesSubplot:xlabel='Author', ylabel='Year'>
